# %%
from copy import deepcopy

import numpy as np

from openscm.units import unit_registry
from openscm.models import PH99Model

import matplotlib.pyplot as plt
plt.style.use('seaborn-dark')

# %%
ph99 = PH99Model()

# %%
ph99.emissions = np.sin(np.linspace(0, 100, 100)) * unit_registry("GtC/yr")
# I need to add a setter which sets other arrays based on length of emissions
# and does re-setting etc.
# temporary workaround
initialiser = np.nan * np.zeros_like(ph99.emissions)

cumulative_emissions_init = deepcopy(initialiser)
cumulative_emissions_init[0] = 0
ph99.cumulative_emissions = unit_registry.Quantity(
    cumulative_emissions_init,
    "GtC"
)

concentrations_init = deepcopy(initialiser)
concentrations_init[0] = 291
ph99.concentrations = unit_registry.Quantity(
    concentrations_init,
    "ppm"
)

temperatures_init = deepcopy(initialiser)
temperatures_init[0] = 14.6
ph99.temperatures = unit_registry.Quantity(
    temperatures_init,
    "degC"
)
# Out:
# /Users/zebedeenicholls/Documents/AGCEC/MCastle/openscm/venv/lib/python3.6/site-packages/pint/quantity.py:1375: UnitStrippedWarning: The unit of the quantity is stripped.
#   warnings.warn("The unit of the quantity is stripped.", UnitStrippedWarning)

# %%
plt.plot(ph99.emissions)
ph99.emissions
# Out:
# array([ 0.        ,  0.84688556,  0.90070545,  0.11106004, -0.7825875 ,
#        -0.94338126, -0.22074597,  0.7086068 ,  0.97438499,  0.32770071,
#        -0.62585878, -0.99333304, -0.43060093,  0.53536727,  0.99999098,
#         0.5281735 , -0.43825186, -0.99427643, -0.61921119,  0.33571414,
#         0.97626009,  0.70258763, -0.22902277, -0.94616487, -0.77727122,
#         0.11949778,  0.90436313,  0.84233795, -0.0084943 , -0.85137207,
#        -0.89698277, -0.10261428,  0.78784731,  0.94052958,  0.21245326,
#        -0.71457484, -0.97243958, -0.31966363,  0.63246122,  0.99231798,
#         0.42291893, -0.5425224 , -0.99991883, -0.52094163,  0.44587117,
#         0.99514807,  0.61251892, -0.34370335, -0.97806475, -0.69651776,
#         0.23728303,  0.94888021,  0.77189886, -0.1279269 , -0.90795556,
#        -0.83772956,  0.01698798,  0.85579714,  0.89319537,  0.09416112,
#        -0.79305028, -0.93761003, -0.20414521,  0.72049132,  0.97042401,
#         0.31160349, -0.63901801, -0.99123132, -0.41520642,  0.54963839,
#         0.99977452,  0.51367217, -0.45345831, -0.99594791, -0.60578245,
#         0.35166777,  0.97979883,  0.69039764, -0.24552618, -0.95152709,
#        -0.7664708 ,  0.13634679,  0.91148248,  0.83306073, -0.02548044,
#        -0.86016046, -0.88934353, -0.08570117,  0.79819602,  0.93462283,
#         0.19582243, -0.72635582, -0.96833842, -0.30352086,  0.6455287 ,
#         0.99007314,  0.40746394, -0.55671472, -0.99955808, -0.50636564]) <Unit('gigatC / a')>

# %%
ph99.temperatures
# Out:
# array([14.6,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,
#         nan]) <Unit('degC')>

# %%
ph99.run()

# %%
ph99.cumulative_emissions
# Out:
# array([ 0.        ,  0.        ,  0.84688556,  1.74759101,  1.85865105,
#         1.07606355,  0.13268229, -0.08806369,  0.62054311,  1.5949281 ,
#         1.92262881,  1.29677003,  0.30343698, -0.12716395,  0.40820332,
#         1.4081943 ,  1.9363678 ,  1.49811594,  0.50383951, -0.11537168,
#         0.22034246,  1.19660255,  1.89919018,  1.67016741,  0.72400254,
#        -0.05326869,  0.0662291 ,  0.97059223,  1.81293018,  1.80443588,
#         0.95306382,  0.05608104, -0.04653324,  0.74131408,  1.68184365,
#         1.89429691,  1.17972207,  0.20728249, -0.11238114,  0.52008007,
#         1.51239806,  1.93531699,  1.39279459,  0.39287576, -0.12806587,
#         0.3178053 ,  1.31295338,  1.9254723 ,  1.58176894,  0.6037042 ,
#        -0.09281356,  0.14446947,  1.09334968,  1.86524854,  1.73732164,
#         0.82936608, -0.00836349,  0.0086245 ,  0.86442164,  1.75761701,
#         1.85177813,  1.05872785,  0.12111782, -0.08302739,  0.63746394,
#         1.60788795,  1.91949144,  1.28047342,  0.2892421 , -0.12596432,
#         0.42367407,  1.42344859,  1.93712076,  1.48366245,  0.48771454,
#        -0.11806791,  0.23359985,  1.21339868,  1.90379632,  1.65827014,
#         0.70674305, -0.05972775,  0.07661904,  0.98810152,  1.82116225,
#         1.79568181,  0.93552135,  0.04617782, -0.03952335,  0.75867268,
#         1.69329551,  1.88911794,  1.16276212,  0.1944237 , -0.10909716,
#         0.53643154,  1.52650469,  1.93396863,  1.37725391,  0.37769583]) <Unit('gigatC')>

# %%
plt.plot(ph99.cumulative_emissions);

# %%
plt.plot(ph99.concentrations);

# %%
plt.plot(ph99.temperatures);
